# %% [markdown]
# # Data Augmentation on Venice Facade Dataset
# Randomly generate irregular patches (noise, or missing parts) on current complete facade to generate complete-incomplete facade pairs.

# %%
import os
import numpy as np
from PIL import Image, ImageDraw
import random
import matplotlib.pyplot as plt

def create_random_irregular_mask(image, max_patches, min_vertices, max_vertices, min_size, max_size):
    """
    Generate a random mask with irregularly shaped missing parts on an image.
    
    Parameters:
        image (PIL.Image): The complete facade image to add missing parts to.
        max_patches (int): Maximum number of missing patches to generate.
        min_vertices (int): Minimum number of vertices for each polygon (irregular shape).
        max_vertices (int): Maximum number of vertices for each polygon (irregular shape).
        min_size (int): Minimum size of a missing patch.
        max_size (int): Maximum size of a missing patch.
        
    Returns:
        masked_image (PIL.Image): Image with randomly generated irregular missing parts.
    """
    masked_image = image.copy()
    draw = ImageDraw.Draw(masked_image)
    width, height = image.size

    for _ in range(random.randint(1, max_patches)):
        # Randomly determine the number of vertices for the polygon
        num_vertices = random.randint(min_vertices, max_vertices)
        
        # Generate random points for the polygon
        polygon = []
        for _ in range(num_vertices):
            angle = random.uniform(0, 2 * np.pi)
            radius = random.uniform(min_size, max_size)
            x = int(width / 2 + radius * np.cos(angle))
            y = int(height / 2 + radius * np.sin(angle))
            polygon.append((x, y))
        
        # Translate polygon to a random position within the image boundaries
        dx = random.randint(-width // 4, width // 4)
        dy = random.randint(-height // 4, height // 4)
        polygon = [(x + dx, y + dy) for (x, y) in polygon]

        # Draw the irregular polygon as a missing part (black area)
        draw.polygon(polygon, fill=(0, 0, 0))
    
    return masked_image

def visualize_random_masks_on_images(image_paths, max_patches, min_vertices, max_vertices, min_size, max_size):
    """
    Apply random irregular masks to images and visualize before and after masking.
    
    Parameters:
        image_paths (list of str): List of paths to 3 complete facade images.
        max_patches (int): Maximum number of missing patches per image.
        min_vertices (int): Minimum number of vertices for each irregular patch.
        max_vertices (int): Maximum number of vertices for each irregular patch.
        min_size (int): Minimum size of a missing patch.
        max_size (int): Maximum size of a missing patch.
    """
    fig, axs = plt.subplots(3, 2, figsize=(10, 15))
    
    for i, image_path in enumerate(image_paths):
        image = Image.open(image_path).convert("RGB")
        # Create a masked version of the image
        masked_image = create_random_irregular_mask(image, max_patches, min_vertices, max_vertices, min_size, max_size)
       
        # Plot original and masked images side by side
        axs[i, 0].imshow(image)
        axs[i, 0].set_title("Original Image")
        axs[i, 0].axis("off")
        
        axs[i, 1].imshow(masked_image)
        axs[i, 1].set_title("Masked Image")
        axs[i, 1].axis("off")
    
    plt.tight_layout()
    plt.show()

# Example usage with 3 image paths
image_paths = [
    'data/complete_facades/images/2_[uid_W001]_.png', 
    'data/complete_facades/images/14_[uid_W013]_.png', 
    'data/complete_facades/images/19_[uid_0136]_.png'  
]

#TODO This can be adapted later based on the missing part 
# property analysis on incomplete facade.
max_patches=2
min_vertices=3
max_vertices=5
min_size=1000
max_size=4000
visualize_random_masks_on_images(image_paths, max_patches, min_vertices, max_vertices, min_size, max_size)

# %%
def apply_random_irregular_masks_to_folder(input_folder, output_folder, num_masks_per_image=3):
    """
    Apply random irregular masks to all images in a folder, simulating missing parts.

    Parameters:
        input_folder (str): Path to the folder containing complete facade images.
        output_folder (str): Path to save the masked images.
        num_masks_per_image (int): Number of masked images to generate per input image.
        max_patches (int): Maximum number of missing patches per image.
        min_vertices (int): Minimum number of vertices for each irregular patch.
        max_vertices (int): Maximum number of vertices for each irregular patch.
        min_size (int): Minimum size of a missing patch.
        max_size (int): Maximum size of a missing patch.
    """
    os.makedirs(output_folder, exist_ok=True)
    
    for file_name in os.listdir(input_folder):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Load the original image
            image_path = os.path.join(input_folder, file_name)
            image = Image.open(image_path).convert("RGB")
            
            # Generate specified number of masked images for each original image
            for i in range(num_masks_per_image):
                masked_image = create_random_irregular_mask(image, max_patches, min_vertices, max_vertices, min_size, max_size)
                
                # Save each masked image with a unique name
                output_path = os.path.join(output_folder, f"masked_{i+1}_{file_name}")
                masked_image.save(output_path)
                print(f"Saved masked image at {output_path}")

num_masks_per_image = 5
input_folder = 'data/complete_facades/images'  
output_folder = 'data/training_aug'   
apply_random_irregular_masks_to_folder(input_folder, output_folder)
# Out:
# Saved masked image at data/training_aug/masked_1_7924_[uid_W098]_.png
# Saved masked image at data/training_aug/masked_2_7924_[uid_W098]_.png
# Saved masked image at data/training_aug/masked_3_7924_[uid_W098]_.png
# Saved masked image at data/training_aug/masked_1_8468_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_2_8468_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_3_8468_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_1_366_[uid_0175]_.png
# Saved masked image at data/training_aug/masked_2_366_[uid_0175]_.png
# Saved masked image at data/training_aug/masked_3_366_[uid_0175]_.png
# Saved masked image at data/training_aug/masked_1_7792_[uid_W117]_.png
# Saved masked image at data/training_aug/masked_2_7792_[uid_W117]_.png
# Saved masked image at data/training_aug/masked_3_7792_[uid_W117]_.png
# Saved masked image at data/training_aug/masked_1_1126_[uid_0047]_.png
# Saved masked image at data/training_aug/masked_2_1126_[uid_0047]_.png
# Saved masked image at data/training_aug/masked_3_1126_[uid_0047]_.png
# Saved masked image at data/training_aug/masked_1_3570_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_2_3570_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_3_3570_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_1_392_[uid_W038]_.png
# Saved masked image at data/training_aug/masked_2_392_[uid_W038]_.png
# Saved masked image at data/training_aug/masked_3_392_[uid_W038]_.png
# Saved masked image at data/training_aug/masked_1_6419_[uid_W063]_.png
# Saved masked image at data/training_aug/masked_2_6419_[uid_W063]_.png
# Saved masked image at data/training_aug/masked_3_6419_[uid_W063]_.png
# Saved masked image at data/training_aug/masked_1_3044_[uid_W069]_.png
# Saved masked image at data/training_aug/masked_2_3044_[uid_W069]_.png
# Saved masked image at data/training_aug/masked_3_3044_[uid_W069]_.png
# Saved masked image at data/training_aug/masked_1_1023_[uid_0214]_.png
# Saved masked image at data/training_aug/masked_2_1023_[uid_0214]_.png
# Saved masked image at data/training_aug/masked_3_1023_[uid_0214]_.png
# Saved masked image at data/training_aug/masked_1_6432_[uid_0027]_.png
# Saved masked image at data/training_aug/masked_2_6432_[uid_0027]_.png
# Saved masked image at data/training_aug/masked_3_6432_[uid_0027]_.png
# Saved masked image at data/training_aug/masked_1_1219_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_2_1219_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_3_1219_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_1_44_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_2_44_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_3_44_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_1_1520_[uid_W041]_.png
# Saved masked image at data/training_aug/masked_2_1520_[uid_W041]_.png
# Saved masked image at data/training_aug/masked_3_1520_[uid_W041]_.png
# Saved masked image at data/training_aug/masked_1_893_[uid_0268]_.png
# Saved masked image at data/training_aug/masked_2_893_[uid_0268]_.png
# Saved masked image at data/training_aug/masked_3_893_[uid_0268]_.png
# Saved masked image at data/training_aug/masked_1_527_[uid_0390]_.png
# Saved masked image at data/training_aug/masked_2_527_[uid_0390]_.png
# Saved masked image at data/training_aug/masked_3_527_[uid_0390]_.png
# Saved masked image at data/training_aug/masked_1_3604_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_2_3604_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_3_3604_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_1_7867_[uid_0850]_.png
# Saved masked image at data/training_aug/masked_2_7867_[uid_0850]_.png
# Saved masked image at data/training_aug/masked_3_7867_[uid_0850]_.png
# Saved masked image at data/training_aug/masked_1_6904_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_6904_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_6904_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_1329_[uid_0159]_.png
# Saved masked image at data/training_aug/masked_2_1329_[uid_0159]_.png
# Saved masked image at data/training_aug/masked_3_1329_[uid_0159]_.png
# Saved masked image at data/training_aug/masked_1_3134_[uid_W026]_.png
# Saved masked image at data/training_aug/masked_2_3134_[uid_W026]_.png
# Saved masked image at data/training_aug/masked_3_3134_[uid_W026]_.png
# Saved masked image at data/training_aug/masked_1_921_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_921_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_921_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_2732_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_2_2732_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_3_2732_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_1_834_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_2_834_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_3_834_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_1_8509_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_8509_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_8509_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_4239_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_4239_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_4239_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_8494_[uid_W022]_.png
# Saved masked image at data/training_aug/masked_2_8494_[uid_W022]_.png
# Saved masked image at data/training_aug/masked_3_8494_[uid_W022]_.png
# Saved masked image at data/training_aug/masked_1_7922_[uid_0020]_.png
# Saved masked image at data/training_aug/masked_2_7922_[uid_0020]_.png
# Saved masked image at data/training_aug/masked_3_7922_[uid_0020]_.png
# Saved masked image at data/training_aug/masked_1_8143_[uid_0740]_.png
# Saved masked image at data/training_aug/masked_2_8143_[uid_0740]_.png
# Saved masked image at data/training_aug/masked_3_8143_[uid_0740]_.png
# Saved masked image at data/training_aug/masked_1_2041_[uid_W035]_.png
# Saved masked image at data/training_aug/masked_2_2041_[uid_W035]_.png
# Saved masked image at data/training_aug/masked_3_2041_[uid_W035]_.png
# Saved masked image at data/training_aug/masked_1_2912_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_2_2912_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_3_2912_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_1_2836_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_2_2836_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_3_2836_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_1_7862_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_7862_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_7862_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_6903_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_6903_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_6903_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_1197_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_2_1197_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_3_1197_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_1_35_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_35_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_35_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_1836_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_2_1836_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_3_1836_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_1_4228_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_4228_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_4228_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_7453_[uid_W143]_.png
# Saved masked image at data/training_aug/masked_2_7453_[uid_W143]_.png
# Saved masked image at data/training_aug/masked_3_7453_[uid_W143]_.png
# Saved masked image at data/training_aug/masked_1_930_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_930_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_930_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_1604_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_2_1604_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_3_1604_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_1_6886_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_6886_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_6886_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_7632_[uid_W130]_.png
# Saved masked image at data/training_aug/masked_2_7632_[uid_W130]_.png
# Saved masked image at data/training_aug/masked_3_7632_[uid_W130]_.png
# Saved masked image at data/training_aug/masked_1_174_[uid_W126]_.png
# Saved masked image at data/training_aug/masked_2_174_[uid_W126]_.png
# Saved masked image at data/training_aug/masked_3_174_[uid_W126]_.png
# Saved masked image at data/training_aug/masked_1_1518_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_2_1518_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_3_1518_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_1_1030_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_1030_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_1030_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_7810_[uid_W143]_.png
# Saved masked image at data/training_aug/masked_2_7810_[uid_W143]_.png
# Saved masked image at data/training_aug/masked_3_7810_[uid_W143]_.png
# Saved masked image at data/training_aug/masked_1_354_[uid_0035]_.png
# Saved masked image at data/training_aug/masked_2_354_[uid_0035]_.png
# Saved masked image at data/training_aug/masked_3_354_[uid_0035]_.png
# Saved masked image at data/training_aug/masked_1_1758_[uid_W074]_.png
# Saved masked image at data/training_aug/masked_2_1758_[uid_W074]_.png
# Saved masked image at data/training_aug/masked_3_1758_[uid_W074]_.png
# Saved masked image at data/training_aug/masked_1_1074_[uid_0035]_.png
# Saved masked image at data/training_aug/masked_2_1074_[uid_0035]_.png
# Saved masked image at data/training_aug/masked_3_1074_[uid_0035]_.png
# Saved masked image at data/training_aug/masked_1_4561_[uid_W021]_.png
# Saved masked image at data/training_aug/masked_2_4561_[uid_W021]_.png
# Saved masked image at data/training_aug/masked_3_4561_[uid_W021]_.png
# Saved masked image at data/training_aug/masked_1_2408_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_2_2408_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_3_2408_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_1_527_[uid_0404]_.png
# Saved masked image at data/training_aug/masked_2_527_[uid_0404]_.png
# Saved masked image at data/training_aug/masked_3_527_[uid_0404]_.png
# Saved masked image at data/training_aug/masked_1_6385_[uid_0226]_.png
# Saved masked image at data/training_aug/masked_2_6385_[uid_0226]_.png
# Saved masked image at data/training_aug/masked_3_6385_[uid_0226]_.png
# Saved masked image at data/training_aug/masked_1_7452_[uid_W104]_.png
# Saved masked image at data/training_aug/masked_2_7452_[uid_W104]_.png
# Saved masked image at data/training_aug/masked_3_7452_[uid_W104]_.png
# Saved masked image at data/training_aug/masked_1_2813_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_2_2813_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_3_2813_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_1_509_[uid_W025]_.png
# Saved masked image at data/training_aug/masked_2_509_[uid_W025]_.png
# Saved masked image at data/training_aug/masked_3_509_[uid_W025]_.png
# Saved masked image at data/training_aug/masked_1_45_[uid_0175]_.png
# Saved masked image at data/training_aug/masked_2_45_[uid_0175]_.png
# Saved masked image at data/training_aug/masked_3_45_[uid_0175]_.png
# Saved masked image at data/training_aug/masked_1_765_[uid_0123]_.png
# Saved masked image at data/training_aug/masked_2_765_[uid_0123]_.png
# Saved masked image at data/training_aug/masked_3_765_[uid_0123]_.png
# Saved masked image at data/training_aug/masked_1_4339_[uid_0550]_.png
# Saved masked image at data/training_aug/masked_2_4339_[uid_0550]_.png
# Saved masked image at data/training_aug/masked_3_4339_[uid_0550]_.png
# Saved masked image at data/training_aug/masked_1_7668_[uid_W042]_.png
# Saved masked image at data/training_aug/masked_2_7668_[uid_W042]_.png
# Saved masked image at data/training_aug/masked_3_7668_[uid_W042]_.png
# Saved masked image at data/training_aug/masked_1_14_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_2_14_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_3_14_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_1_1069_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_2_1069_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_3_1069_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_1_1222_[uid_0136]_.png
# Saved masked image at data/training_aug/masked_2_1222_[uid_0136]_.png
# Saved masked image at data/training_aug/masked_3_1222_[uid_0136]_.png
# Saved masked image at data/training_aug/masked_1_180_[uid_W090]_.png
# Saved masked image at data/training_aug/masked_2_180_[uid_W090]_.png
# Saved masked image at data/training_aug/masked_3_180_[uid_W090]_.png
# Saved masked image at data/training_aug/masked_1_7079_[uid_0226]_.png
# Saved masked image at data/training_aug/masked_2_7079_[uid_0226]_.png
# Saved masked image at data/training_aug/masked_3_7079_[uid_0226]_.png
# Saved masked image at data/training_aug/masked_1_4230_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_4230_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_4230_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_4493_[uid_0074]_.png
# Saved masked image at data/training_aug/masked_2_4493_[uid_0074]_.png
# Saved masked image at data/training_aug/masked_3_4493_[uid_0074]_.png
# Saved masked image at data/training_aug/masked_1_392_[uid_W161]_.png
# Saved masked image at data/training_aug/masked_2_392_[uid_W161]_.png
# Saved masked image at data/training_aug/masked_3_392_[uid_W161]_.png
# Saved masked image at data/training_aug/masked_1_7859_[uid_0284]_.png
# Saved masked image at data/training_aug/masked_2_7859_[uid_0284]_.png
# Saved masked image at data/training_aug/masked_3_7859_[uid_0284]_.png
# Saved masked image at data/training_aug/masked_1_620_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_2_620_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_3_620_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_1_3130_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_2_3130_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_3_3130_[uid_W111]_.png
# Saved masked image at data/training_aug/masked_1_7445_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_7445_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_7445_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_4429_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_2_4429_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_3_4429_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_1_4542_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_2_4542_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_3_4542_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_1_496_[uid_0217]_.png
# Saved masked image at data/training_aug/masked_2_496_[uid_0217]_.png
# Saved masked image at data/training_aug/masked_3_496_[uid_0217]_.png
# Saved masked image at data/training_aug/masked_1_2886_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_2_2886_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_3_2886_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_1_8449_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_8449_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_8449_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_658_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_2_658_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_3_658_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_1_1114_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_2_1114_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_3_1114_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_1_6987_[uid_W060]_.png
# Saved masked image at data/training_aug/masked_2_6987_[uid_W060]_.png
# Saved masked image at data/training_aug/masked_3_6987_[uid_W060]_.png
# Saved masked image at data/training_aug/masked_1_1271_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_2_1271_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_3_1271_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_1_591_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_2_591_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_3_591_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_1_2622_[uid_0009]_.png
# Saved masked image at data/training_aug/masked_2_2622_[uid_0009]_.png
# Saved masked image at data/training_aug/masked_3_2622_[uid_0009]_.png
# Saved masked image at data/training_aug/masked_1_8325_[uid_W059]_.png
# Saved masked image at data/training_aug/masked_2_8325_[uid_W059]_.png
# Saved masked image at data/training_aug/masked_3_8325_[uid_W059]_.png
# Saved masked image at data/training_aug/masked_1_3442_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_2_3442_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_3_3442_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_1_3186_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_2_3186_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_3_3186_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_1_1580_[uid_2156]_.png
# Saved masked image at data/training_aug/masked_2_1580_[uid_2156]_.png
# Saved masked image at data/training_aug/masked_3_1580_[uid_2156]_.png
# Saved masked image at data/training_aug/masked_1_8421_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_2_8421_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_3_8421_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_1_693_[uid_W038]_.png
# Saved masked image at data/training_aug/masked_2_693_[uid_W038]_.png
# Saved masked image at data/training_aug/masked_3_693_[uid_W038]_.png
# Saved masked image at data/training_aug/masked_1_7456_[uid_0627]_.png
# Saved masked image at data/training_aug/masked_2_7456_[uid_0627]_.png
# Saved masked image at data/training_aug/masked_3_7456_[uid_0627]_.png
# Saved masked image at data/training_aug/masked_1_1482_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_2_1482_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_3_1482_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_1_289_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_2_289_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_3_289_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_1_1046_[uid_W025]_.png
# Saved masked image at data/training_aug/masked_2_1046_[uid_W025]_.png
# Saved masked image at data/training_aug/masked_3_1046_[uid_W025]_.png
# Saved masked image at data/training_aug/masked_1_1578_[uid_0781]_.png
# Saved masked image at data/training_aug/masked_2_1578_[uid_0781]_.png
# Saved masked image at data/training_aug/masked_3_1578_[uid_0781]_.png
# Saved masked image at data/training_aug/masked_1_2413_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_2_2413_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_3_2413_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_1_1577_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_2_1577_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_3_1577_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_1_1360_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_2_1360_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_3_1360_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_1_3148_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_2_3148_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_3_3148_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_1_7566_[uid_0156]_.png
# Saved masked image at data/training_aug/masked_2_7566_[uid_0156]_.png
# Saved masked image at data/training_aug/masked_3_7566_[uid_0156]_.png
# Saved masked image at data/training_aug/masked_1_7823_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_2_7823_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_3_7823_[uid_W075]_.png
# Saved masked image at data/training_aug/masked_1_7418_[uid_0530]_.png
# Saved masked image at data/training_aug/masked_2_7418_[uid_0530]_.png
# Saved masked image at data/training_aug/masked_3_7418_[uid_0530]_.png
# Saved masked image at data/training_aug/masked_1_749_[uid_0254]_.png
# Saved masked image at data/training_aug/masked_2_749_[uid_0254]_.png
# Saved masked image at data/training_aug/masked_3_749_[uid_0254]_.png
# Saved masked image at data/training_aug/masked_1_91_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_2_91_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_3_91_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_1_3626_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_3626_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_3626_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_4326_[uid_W117]_.png
# Saved masked image at data/training_aug/masked_2_4326_[uid_W117]_.png
# Saved masked image at data/training_aug/masked_3_4326_[uid_W117]_.png
# Saved masked image at data/training_aug/masked_1_667_[uid_W163]_.png
# Saved masked image at data/training_aug/masked_2_667_[uid_W163]_.png
# Saved masked image at data/training_aug/masked_3_667_[uid_W163]_.png
# Saved masked image at data/training_aug/masked_1_381_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_2_381_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_3_381_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_1_2_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_2_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_2_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_4332_[uid_W158]_.png
# Saved masked image at data/training_aug/masked_2_4332_[uid_W158]_.png
# Saved masked image at data/training_aug/masked_3_4332_[uid_W158]_.png
# Saved masked image at data/training_aug/masked_1_6643_[uid_W079]_.png
# Saved masked image at data/training_aug/masked_2_6643_[uid_W079]_.png
# Saved masked image at data/training_aug/masked_3_6643_[uid_W079]_.png
# Saved masked image at data/training_aug/masked_1_914_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_2_914_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_3_914_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_1_901_[uid_0630]_.png
# Saved masked image at data/training_aug/masked_2_901_[uid_0630]_.png
# Saved masked image at data/training_aug/masked_3_901_[uid_0630]_.png
# Saved masked image at data/training_aug/masked_1_2739_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_2_2739_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_3_2739_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_1_1114_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_2_1114_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_3_1114_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_1_262_[uid_W074]_.png
# Saved masked image at data/training_aug/masked_2_262_[uid_W074]_.png
# Saved masked image at data/training_aug/masked_3_262_[uid_W074]_.png
# Saved masked image at data/training_aug/masked_1_795_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_2_795_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_3_795_[uid_0016]_.png
# Saved masked image at data/training_aug/masked_1_6639_[uid_W079]_.png
# Saved masked image at data/training_aug/masked_2_6639_[uid_W079]_.png
# Saved masked image at data/training_aug/masked_3_6639_[uid_W079]_.png
# Saved masked image at data/training_aug/masked_1_7898_[uid_W102]_.png
# Saved masked image at data/training_aug/masked_2_7898_[uid_W102]_.png
# Saved masked image at data/training_aug/masked_3_7898_[uid_W102]_.png
# Saved masked image at data/training_aug/masked_1_1028_[uid_0463]_.png
# Saved masked image at data/training_aug/masked_2_1028_[uid_0463]_.png
# Saved masked image at data/training_aug/masked_3_1028_[uid_0463]_.png
# Saved masked image at data/training_aug/masked_1_4359_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_4359_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_4359_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_322_[uid_W052]_.png
# Saved masked image at data/training_aug/masked_2_322_[uid_W052]_.png
# Saved masked image at data/training_aug/masked_3_322_[uid_W052]_.png
# Saved masked image at data/training_aug/masked_1_4377_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_2_4377_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_3_4377_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_1_2767_[uid_W133]_.png
# Saved masked image at data/training_aug/masked_2_2767_[uid_W133]_.png
# Saved masked image at data/training_aug/masked_3_2767_[uid_W133]_.png
# Saved masked image at data/training_aug/masked_1_6429_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_6429_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_6429_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_2875_[uid_W133]_.png
# Saved masked image at data/training_aug/masked_2_2875_[uid_W133]_.png
# Saved masked image at data/training_aug/masked_3_2875_[uid_W133]_.png
# Saved masked image at data/training_aug/masked_1_3493_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_2_3493_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_3_3493_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_1_3074_[uid_W077]_.png
# Saved masked image at data/training_aug/masked_2_3074_[uid_W077]_.png
# Saved masked image at data/training_aug/masked_3_3074_[uid_W077]_.png
# Saved masked image at data/training_aug/masked_1_1033_[uid_W064]_.png
# Saved masked image at data/training_aug/masked_2_1033_[uid_W064]_.png
# Saved masked image at data/training_aug/masked_3_1033_[uid_W064]_.png
# Saved masked image at data/training_aug/masked_1_4302_[uid_W031]_.png
# Saved masked image at data/training_aug/masked_2_4302_[uid_W031]_.png
# Saved masked image at data/training_aug/masked_3_4302_[uid_W031]_.png
# Saved masked image at data/training_aug/masked_1_892_[uid_0983]_.png
# Saved masked image at data/training_aug/masked_2_892_[uid_0983]_.png
# Saved masked image at data/training_aug/masked_3_892_[uid_0983]_.png
# Saved masked image at data/training_aug/masked_1_4272_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_4272_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_4272_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_221_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_221_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_221_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_3001_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_2_3001_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_3_3001_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_1_1857_[uid_1520]_.png
# Saved masked image at data/training_aug/masked_2_1857_[uid_1520]_.png
# Saved masked image at data/training_aug/masked_3_1857_[uid_1520]_.png
# Saved masked image at data/training_aug/masked_1_4443_[uid_0093]_.png
# Saved masked image at data/training_aug/masked_2_4443_[uid_0093]_.png
# Saved masked image at data/training_aug/masked_3_4443_[uid_0093]_.png
# Saved masked image at data/training_aug/masked_1_19_[uid_0136]_.png
# Saved masked image at data/training_aug/masked_2_19_[uid_0136]_.png
# Saved masked image at data/training_aug/masked_3_19_[uid_0136]_.png
# Saved masked image at data/training_aug/masked_1_1705_[uid_W077]_.png
# Saved masked image at data/training_aug/masked_2_1705_[uid_W077]_.png
# Saved masked image at data/training_aug/masked_3_1705_[uid_W077]_.png
# Saved masked image at data/training_aug/masked_1_903_[uid_0404]_.png
# Saved masked image at data/training_aug/masked_2_903_[uid_0404]_.png
# Saved masked image at data/training_aug/masked_3_903_[uid_0404]_.png
# Saved masked image at data/training_aug/masked_1_3245_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_3245_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_3245_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_469_[uid_0789]_.png
# Saved masked image at data/training_aug/masked_2_469_[uid_0789]_.png
# Saved masked image at data/training_aug/masked_3_469_[uid_0789]_.png
# Saved masked image at data/training_aug/masked_1_1616_[uid_W080]_.png
# Saved masked image at data/training_aug/masked_2_1616_[uid_W080]_.png
# Saved masked image at data/training_aug/masked_3_1616_[uid_W080]_.png
# Saved masked image at data/training_aug/masked_1_6605_[uid_W106]_.png
# Saved masked image at data/training_aug/masked_2_6605_[uid_W106]_.png
# Saved masked image at data/training_aug/masked_3_6605_[uid_W106]_.png
# Saved masked image at data/training_aug/masked_1_156_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_2_156_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_3_156_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_1_292_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_2_292_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_3_292_[uid_W089]_.png
# Saved masked image at data/training_aug/masked_1_329_[uid_W062]_.png
# Saved masked image at data/training_aug/masked_2_329_[uid_W062]_.png
# Saved masked image at data/training_aug/masked_3_329_[uid_W062]_.png
# Saved masked image at data/training_aug/masked_1_8042_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_8042_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_8042_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_6812_[uid_W149]_.png
# Saved masked image at data/training_aug/masked_2_6812_[uid_W149]_.png
# Saved masked image at data/training_aug/masked_3_6812_[uid_W149]_.png
# Saved masked image at data/training_aug/masked_1_2747_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_2_2747_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_3_2747_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_1_108_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_2_108_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_3_108_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_1_1354_[uid_0150]_.png
# Saved masked image at data/training_aug/masked_2_1354_[uid_0150]_.png
# Saved masked image at data/training_aug/masked_3_1354_[uid_0150]_.png
# Saved masked image at data/training_aug/masked_1_2578_[uid_0091]_.png
# Saved masked image at data/training_aug/masked_2_2578_[uid_0091]_.png
# Saved masked image at data/training_aug/masked_3_2578_[uid_0091]_.png
# Saved masked image at data/training_aug/masked_1_7745_[uid_W092]_.png
# Saved masked image at data/training_aug/masked_2_7745_[uid_W092]_.png
# Saved masked image at data/training_aug/masked_3_7745_[uid_W092]_.png
# Saved masked image at data/training_aug/masked_1_2653_[uid_W071]_.png
# Saved masked image at data/training_aug/masked_2_2653_[uid_W071]_.png
# Saved masked image at data/training_aug/masked_3_2653_[uid_W071]_.png
# Saved masked image at data/training_aug/masked_1_1578_[uid_0095]_.png
# Saved masked image at data/training_aug/masked_2_1578_[uid_0095]_.png
# Saved masked image at data/training_aug/masked_3_1578_[uid_0095]_.png
# Saved masked image at data/training_aug/masked_1_666_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_2_666_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_3_666_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_1_1427_[uid_W052]_.png
# Saved masked image at data/training_aug/masked_2_1427_[uid_W052]_.png
# Saved masked image at data/training_aug/masked_3_1427_[uid_W052]_.png
# Saved masked image at data/training_aug/masked_1_1432_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_1432_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_1432_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_2769_[uid_0586]_.png
# Saved masked image at data/training_aug/masked_2_2769_[uid_0586]_.png
# Saved masked image at data/training_aug/masked_3_2769_[uid_0586]_.png
# Saved masked image at data/training_aug/masked_1_3805_[uid_W116]_.png
# Saved masked image at data/training_aug/masked_2_3805_[uid_W116]_.png
# Saved masked image at data/training_aug/masked_3_3805_[uid_W116]_.png
# Saved masked image at data/training_aug/masked_1_2312_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_2_2312_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_3_2312_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_1_1833_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_2_1833_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_3_1833_[uid_0114]_.png
# Saved masked image at data/training_aug/masked_1_3214_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_2_3214_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_3_3214_[uid_W039]_.png
# Saved masked image at data/training_aug/masked_1_4189_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_2_4189_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_3_4189_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_1_335_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_2_335_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_3_335_[uid_W011]_.png
# Saved masked image at data/training_aug/masked_1_1748_[uid_W081]_.png
# Saved masked image at data/training_aug/masked_2_1748_[uid_W081]_.png
# Saved masked image at data/training_aug/masked_3_1748_[uid_W081]_.png
# Saved masked image at data/training_aug/masked_1_1412_[uid_W150]_.png
# Saved masked image at data/training_aug/masked_2_1412_[uid_W150]_.png
# Saved masked image at data/training_aug/masked_3_1412_[uid_W150]_.png
# Saved masked image at data/training_aug/masked_1_933_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_2_933_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_3_933_[uid_W085]_.png
# Saved masked image at data/training_aug/masked_1_7449_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_7449_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_7449_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_112_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_2_112_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_3_112_[uid_W020]_.png
# Saved masked image at data/training_aug/masked_1_3048_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_2_3048_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_3_3048_[uid_W051]_.png
# Saved masked image at data/training_aug/masked_1_26_[uid_W107]_.png
# Saved masked image at data/training_aug/masked_2_26_[uid_W107]_.png
# Saved masked image at data/training_aug/masked_3_26_[uid_W107]_.png
# Saved masked image at data/training_aug/masked_1_208_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_2_208_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_3_208_[uid_W049]_.png
# Saved masked image at data/training_aug/masked_1_4700_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_2_4700_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_3_4700_[uid_W023]_.png
# Saved masked image at data/training_aug/masked_1_2358_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_2_2358_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_3_2358_[uid_W005]_.png
# Saved masked image at data/training_aug/masked_1_1138_[uid_0738]_.png
# Saved masked image at data/training_aug/masked_2_1138_[uid_0738]_.png
# Saved masked image at data/training_aug/masked_3_1138_[uid_0738]_.png
# Saved masked image at data/training_aug/masked_1_4329_[uid_W110]_.png
# Saved masked image at data/training_aug/masked_2_4329_[uid_W110]_.png
# Saved masked image at data/training_aug/masked_3_4329_[uid_W110]_.png
# Saved masked image at data/training_aug/masked_1_849_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_2_849_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_3_849_[uid_W024]_.png
# Saved masked image at data/training_aug/masked_1_1405_[uid_0463]_.png
# Saved masked image at data/training_aug/masked_2_1405_[uid_0463]_.png
# Saved masked image at data/training_aug/masked_3_1405_[uid_0463]_.png
# Saved masked image at data/training_aug/masked_1_8105_[uid_W022]_.png
# Saved masked image at data/training_aug/masked_2_8105_[uid_W022]_.png
# Saved masked image at data/training_aug/masked_3_8105_[uid_W022]_.png
# Saved masked image at data/training_aug/masked_1_629_[uid_0086]_.png
# Saved masked image at data/training_aug/masked_2_629_[uid_0086]_.png
# Saved masked image at data/training_aug/masked_3_629_[uid_0086]_.png
# Saved masked image at data/training_aug/masked_1_1521_[uid_0271]_.png
# Saved masked image at data/training_aug/masked_2_1521_[uid_0271]_.png
# Saved masked image at data/training_aug/masked_3_1521_[uid_0271]_.png
# Saved masked image at data/training_aug/masked_1_3836_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_2_3836_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_3_3836_[uid_W072]_.png
# Saved masked image at data/training_aug/masked_1_8283_[uid_0479]_.png
# Saved masked image at data/training_aug/masked_2_8283_[uid_0479]_.png
# Saved masked image at data/training_aug/masked_3_8283_[uid_0479]_.png
# Saved masked image at data/training_aug/masked_1_2910_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_2_2910_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_3_2910_[uid_0191]_.png
# Saved masked image at data/training_aug/masked_1_191_[uid_0043]_.png
# Saved masked image at data/training_aug/masked_2_191_[uid_0043]_.png
# Saved masked image at data/training_aug/masked_3_191_[uid_0043]_.png
# Saved masked image at data/training_aug/masked_1_7595_[uid_W123]_.png
# Saved masked image at data/training_aug/masked_2_7595_[uid_W123]_.png
# Saved masked image at data/training_aug/masked_3_7595_[uid_W123]_.png
# Saved masked image at data/training_aug/masked_1_3524_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_2_3524_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_3_3524_[uid_W055]_.png
# Saved masked image at data/training_aug/masked_1_6884_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_6884_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_6884_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_869_[uid_0150]_.png
# Saved masked image at data/training_aug/masked_2_869_[uid_0150]_.png
# Saved masked image at data/training_aug/masked_3_869_[uid_0150]_.png
# Saved masked image at data/training_aug/masked_1_3242_[uid_W067]_.png
# Saved masked image at data/training_aug/masked_2_3242_[uid_W067]_.png
# Saved masked image at data/training_aug/masked_3_3242_[uid_W067]_.png
# Saved masked image at data/training_aug/masked_1_176_[uid_W126]_.png
# Saved masked image at data/training_aug/masked_2_176_[uid_W126]_.png
# Saved masked image at data/training_aug/masked_3_176_[uid_W126]_.png
# Saved masked image at data/training_aug/masked_1_422_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_2_422_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_3_422_[uid_W013]_.png
# Saved masked image at data/training_aug/masked_1_3236_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_2_3236_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_3_3236_[uid_W001]_.png
# Saved masked image at data/training_aug/masked_1_2647_[uid_1003]_.png
# Saved masked image at data/training_aug/masked_2_2647_[uid_1003]_.png
# Saved masked image at data/training_aug/masked_3_2647_[uid_1003]_.png
# Saved masked image at data/training_aug/masked_1_1889_[uid_W026]_.png
# Saved masked image at data/training_aug/masked_2_1889_[uid_W026]_.png
# Saved masked image at data/training_aug/masked_3_1889_[uid_W026]_.png
# Saved masked image at data/training_aug/masked_1_4410_[uid_W007]_.png
# Saved masked image at data/training_aug/masked_2_4410_[uid_W007]_.png
# Saved masked image at data/training_aug/masked_3_4410_[uid_W007]_.png
# Saved masked image at data/training_aug/masked_1_6951_[uid_W124]_.png
# Saved masked image at data/training_aug/masked_2_6951_[uid_W124]_.png
# Saved masked image at data/training_aug/masked_3_6951_[uid_W124]_.png
# Saved masked image at data/training_aug/masked_1_8142_[uid_W058]_.png
# Saved masked image at data/training_aug/masked_2_8142_[uid_W058]_.png
# Saved masked image at data/training_aug/masked_3_8142_[uid_W058]_.png
# Saved masked image at data/training_aug/masked_1_3556_[uid_W048]_.png
# Saved masked image at data/training_aug/masked_2_3556_[uid_W048]_.png
# Saved masked image at data/training_aug/masked_3_3556_[uid_W048]_.png
